# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing data from Excel file

# %%
df=pd.read_csv('50_Startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
X=df.iloc[:,:-1].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
y=df.iloc[:,4].values
y
# Out:
# array([ 192261.83,  191792.06,  191050.39,  182901.99,  166187.94,
#         156991.12,  156122.51,  155752.6 ,  152211.77,  149759.96,
#         146121.95,  144259.4 ,  141585.52,  134307.35,  132602.65,
#         129917.04,  126992.93,  125370.37,  124266.9 ,  122776.86,
#         118474.03,  111313.02,  110352.25,  108733.99,  108552.04,
#         107404.34,  105733.54,  105008.31,  103282.38,  101004.64,
#          99937.59,   97483.56,   97427.84,   96778.92,   96712.8 ,
#          96479.51,   90708.19,   89949.14,   81229.06,   81005.76,
#          78239.91,   77798.83,   71498.49,   69758.98,   65200.33,
#          64926.08,   49490.75,   42559.73,   35673.41,   14681.4 ])

# %%
#Encoding Categorical variables using Labelencoder and onehotencoder

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_X=LabelEncoder()

# %%
X[:,3]=labelencoder_X.fit_transform(X[:,3])
onehotencoder=OneHotEncoder(categorical_features=[3])
X=onehotencoder.fit_transform(X).toarray()

# %%
X
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           1.65349200e+05,   1.36897800e+05,   4.71784100e+05],
#        [  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.62597700e+05,   1.51377590e+05,   4.43898530e+05],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.53441510e+05,   1.01145550e+05,   4.07934540e+05],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           1.44372410e+05,   1.18671850e+05,   3.83199620e+05],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.42107340e+05,   9.13917700e+04,   3.66168420e+05],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           1.31876900e+05,   9.98147100e+04,   3.62861360e+05],
#        [  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.34615460e+05,   1.47198870e+05,   1.27716820e+05],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
# ...

# %%
df.index = df.index.astype(int)

# %%
df_x=pd.DataFrame(X)

# %%
df_x
# Out:
#       0    1    2          3          4          5
# 0   0.0  0.0  1.0  165349.20  136897.80  471784.10
# 1   1.0  0.0  0.0  162597.70  151377.59  443898.53
# 2   0.0  1.0  0.0  153441.51  101145.55  407934.54
# 3   0.0  0.0  1.0  144372.41  118671.85  383199.62
# 4   0.0  1.0  0.0  142107.34   91391.77  366168.42
# 5   0.0  0.0  1.0  131876.90   99814.71  362861.36
# 6   1.0  0.0  0.0  134615.46  147198.87  127716.82
# 7   0.0  1.0  0.0  130298.13  145530.06  323876.68
# 8   0.0  0.0  1.0  120542.52  148718.95  311613.29
# 9   1.0  0.0  0.0  123334.88  108679.17  304981.62
# 10  0.0  1.0  0.0  101913.08  110594.11  229160.95
# 11  1.0  0.0  0.0  100671.96   91790.61  249744.55
# 12  0.0  1.0  0.0   93863.75  127320.38  249839.44
# 13  1.0  0.0  0.0   91992.39  135495.07  252664.93
# 14  0.0  1.0  0.0  119943.24  156547.42  256512.92
# 15  0.0  0.0  1.0  114523.61  122616.84  261776.23
# 16  1.0  0.0  0.0   78013.11  121597.55  264346.06
# ...

# %%
#Avoiding the dummy variable trap

# %%
X=X[:,1:]

# %%
X
# Out:
# array([[  0.00000000e+00,   1.00000000e+00,   1.65349200e+05,
#           1.36897800e+05,   4.71784100e+05],
#        [  0.00000000e+00,   0.00000000e+00,   1.62597700e+05,
#           1.51377590e+05,   4.43898530e+05],
#        [  1.00000000e+00,   0.00000000e+00,   1.53441510e+05,
#           1.01145550e+05,   4.07934540e+05],
#        [  0.00000000e+00,   1.00000000e+00,   1.44372410e+05,
#           1.18671850e+05,   3.83199620e+05],
#        [  1.00000000e+00,   0.00000000e+00,   1.42107340e+05,
#           9.13917700e+04,   3.66168420e+05],
#        [  0.00000000e+00,   1.00000000e+00,   1.31876900e+05,
#           9.98147100e+04,   3.62861360e+05],
#        [  0.00000000e+00,   0.00000000e+00,   1.34615460e+05,
#           1.47198870e+05,   1.27716820e+05],
#        [  1.00000000e+00,   0.00000000e+00,   1.30298130e+05,
#           1.45530060e+05,   3.23876680e+05],
#        [  0.00000000e+00,   1.00000000e+00,   1.20542520e+05,
#           1.48718950e+05,   3.11613290e+05],
# ...

# %%
#Splitting data into training and text sets

# %%
from sklearn.cross_validation import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (40, 5)

# %%
y_train.shape
# Out:
# (40,)

# %%
#Good to go

# %%
#Fitting Multiple linear regression to the training set

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Predicting test set results

# %%
y_pred=lm.predict(X_test)

# %%
y_pred
# Out:
# array([ 103015.20159795,  132582.27760817,  132447.73845176,
#          71976.09851257,  178537.48221058,  116161.24230165,
#          67851.69209675,   98791.73374686,  113969.43533013,
#         167921.06569553])

# %%
y_test
# Out:
# array([ 103282.38,  144259.4 ,  146121.95,   77798.83,  191050.39,
#         105008.31,   81229.06,   97483.56,  110352.25,  166187.94])

# %%
#Lets build an optimal model using backward elimination

# %%
fig,ax=plt.subplots()
ax.scatter(y_test,y_pred)
ax.plt([y.min(),y.max()],[y.min(),y.max()],lw=4)
ax.set_xlabel('y_test')
ax.set_ylabel('predictions')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-931e6ba5cbf6> in <module>()
#       1 fig,ax=plt.subplots()
#       2 ax.scatter(y_test,y_pred)
# ----> 3 ax.plt([y.min(),y.max()],[y.min(),y.max()],lw=4)
#       4 ax.set_xlabel('y_test')
#       5 ax.set_ylabel('predictions')
#
# AttributeError: 'AxesSubplot' object has no attribute 'plt'

# %%
import statsmodels.formula.api as sm
X=np.append(arr=np.ones((50,1)).astype(int),values=X,axis=1)

# %%
X_main=X[:,[0,1,2,3,4,5]]

# %%
lm_OLS=sm.OLS(endog=y,exog=X_main).fit()

# %%
lm_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Wed, 27 Sep 2017   Prob (F-statistic):           1.34e-27
# Time:                        02:16:16   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# ...

# %%
#Lower is the p value more significant the value would be

# %%
#Removing variables with high p values

# %%
X_main=X[:,[0,1,3,4,5]]
lm_OLS=sm.OLS(endog=y,exog=X_main).fit()
lm_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Wed, 27 Sep 2017   Prob (F-statistic):           8.49e-29
# Time:                        02:18:33   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# ...

# %%
X_main=X[:,[0,3,4,5]]
lm_OLS=sm.OLS(endog=y,exog=X_main).fit()
lm_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Wed, 27 Sep 2017   Prob (F-statistic):           4.53e-30
# Time:                        02:19:49   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
X_main=X[:,[3,5]]
lm_OLS=sm.OLS(endog=y,exog=X_main).fit()
lm_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     550.4
# Date:                Wed, 27 Sep 2017   Prob (F-statistic):           8.02e-34
# Time:                        02:20:28   Log-Likelihood:                -575.87
# No. Observations:                  50   AIC:                             1156.
# Df Residuals:                      48   BIC:                             1160.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.9781      0.108      9.026      0.000       0.760       1.196
# ...

# %%
X_main=X[:,[0,3]]
lm_OLS=sm.OLS(endog=y,exog=X_main).fit()
lm_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Wed, 27 Sep 2017   Prob (F-statistic):           3.50e-32
# Time:                        02:21:06   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
#Voila R&D spend is the only amazing factor that influences the profit of the startup companies

# %%
#The Venture Capitalist should invest in companies that spends more on the R&D

# %%
# The End
